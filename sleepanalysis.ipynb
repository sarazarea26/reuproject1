# %%
import pandas as pd

# %%
df = pd.read_csv('sleep_deprivation_dataset_detailed.csv')
df
# Out:
#    Participant_ID  Sleep_Hours  Sleep_Quality_Score  Daytime_Sleepiness  \
# 0              P1         5.25                   15                  12
# 1              P2         8.70                   12                  14
# 2              P3         7.39                   17                  10
# 3              P4         6.59                   14                   3
# 4              P5         3.94                   20                  12
# 5              P6         3.94                   12                   6
# 6              P7         3.35                    8                  18
# 7              P8         8.20                   14                  21
# 8              P9         6.61                   12                   1
# 9             P10         7.25                    0                   9
# 10            P11         3.12                    6                  12
# 11            P12         8.82                    8                  24
# ...

# %%
df.head(5)
# Out:
#   Participant_ID  Sleep_Hours  Sleep_Quality_Score  Daytime_Sleepiness  \
# 0             P1         5.25                   15                  12
# 1             P2         8.70                   12                  14
# 2             P3         7.39                   17                  10
# 3             P4         6.59                   14                   3
# 4             P5         3.94                   20                  12
#
#    Stroop_Task_Reaction_Time  N_Back_Accuracy  Emotion_Regulation_Score  \
# 0                       1.60            64.20                        12
# 1                       2.54            65.27                        21
# 2                       3.40            74.28                        35
# 3                       3.54            72.42                        25
# 4                       3.09            99.72                        60
#
#    PVT_Reaction_Time  Age  Gender    BMI  Caffeine_Intake  \
# ...

# %%
df.describe()
# Out:
#        Sleep_Hours  Sleep_Quality_Score  Daytime_Sleepiness  \
# count    60.000000            60.000000           60.000000
# mean      5.805500             8.316667           12.000000
# std       1.832357             5.637320            7.577845
# min       3.120000             0.000000            0.000000
# 25%       4.107500             4.000000            6.000000
# 50%       5.690000             8.000000           11.500000
# 75%       7.285000            13.000000           19.000000
# max       8.820000            20.000000           24.000000
#
#        Stroop_Task_Reaction_Time  N_Back_Accuracy  Emotion_Regulation_Score  \
# count                  60.000000        60.000000                   60.0000
# mean                    3.245000        75.005833                   38.1500
# std                     0.827368        13.671457                   17.1334
# min                     1.600000        50.900000                   10.0000
# ...

# %%
df['Sleep_Hours'].mean()
# Out:
# np.float64(5.8054999999999986)

# %%
df['Sleep_Quality_Score'].min()
# Out:
# 0

# %%
df['Sleep_Quality_Score'].max()
# Out:
# 20

# %%
df[df['Sleep_Quality_Score'] > 15]
# Out:
#    Participant_ID  Sleep_Hours  Sleep_Quality_Score  Daytime_Sleepiness  \
# 2              P3         7.39                   17                  10
# 4              P5         3.94                   20                  12
# 16            P17         4.83                   18                  19
# 17            P18         6.15                   16                  10
# 53            P54         8.37                   18                  16
# 55            P56         8.53                   16                  16
# 56            P57         3.53                   19                  16
#
#     Stroop_Task_Reaction_Time  N_Back_Accuracy  Emotion_Regulation_Score  \
# 2                        3.40            74.28                        35
# 4                        3.09            99.72                        60
# 16                       3.90            62.52                        61
# 17                       1.95            79.49                        14
# ...

# %%
df[df['Stress_Level'] > 30]
# Out:
#    Participant_ID  Sleep_Hours  Sleep_Quality_Score  Daytime_Sleepiness  \
# 0              P1         5.25                   15                  12
# 1              P2         8.70                   12                  14
# 2              P3         7.39                   17                  10
# 17            P18         6.15                   16                  10
# 29            P30         3.28                   11                   6
# 33            P34         8.69                    4                   4
# 37            P38         3.59                    2                  11
# 48            P49         6.28                    8                   6
# 51            P52         7.65                    9                  16
#
#     Stroop_Task_Reaction_Time  N_Back_Accuracy  Emotion_Regulation_Score  \
# 0                        1.60            64.20                        12
# 1                        2.54            65.27                        21
# ...

# %%
df[df['Emotion_Regulation_Score'] < 10]
# Out:
# Empty DataFrame
# Columns: [Participant_ID, Sleep_Hours, Sleep_Quality_Score, Daytime_Sleepiness, Stroop_Task_Reaction_Time, N_Back_Accuracy, Emotion_Regulation_Score, PVT_Reaction_Time, Age, Gender, BMI, Caffeine_Intake, Physical_Activity_Level, Stress_Level]
# Index: []

# %%
df0 = pd.read_csv('acsdata.csv')
df0
# Out:
#       GEO_ID                  NAME  \
# 0  Geography  Geographic Area Name
# 1  0100000US         United States
#
#                                        DP02_0001E  \
# 0  Estimate!!HOUSEHOLDS BY TYPE!!Total households
# 1                                       132737146
#
#                                           DP02_0001M  \
# 0  Margin of Error!!HOUSEHOLDS BY TYPE!!Total hou...
# 1                                             140273
#
#                                           DP02_0002E  \
# 0  Estimate!!HOUSEHOLDS BY TYPE!!Total households...
# 1                                           61980084
#
#                                           DP02_0002M  \
# 0  Margin of Error!!HOUSEHOLDS BY TYPE!!Total hou...
# 1                                             185731
#
#                                           DP02_0003E  \
# 0  Estimate!!HOUSEHOLDS BY TYPE!!Total households...
# 1                                           22999943
#
# ...
